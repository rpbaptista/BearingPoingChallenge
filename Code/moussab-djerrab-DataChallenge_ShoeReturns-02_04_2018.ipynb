# %% [markdown]
# # <center>Predicting the returns of orders  for a retail shoe seller</center>

# %% [markdown]
# ## Introduction
# ###  Challenge SD210 2018
# #### Authors :  Florence D'Alché & Umut Şimşekli & Moussab Djerrab
#
#
# **Context of the challenge:**
#
# An electronic commerce company sells shoes, and has a high return rate of his products, more than 20%. This large number of returns and exchanges has a negative impact on its margin. To remedy this problem, the company wants to better understand this phenomenon, and have tools to quantify the probability of return for a given product. It makes available its database of orders placed between October 2011 and October 2015, its product feedback data, and its customer and product databases (provide the data dictionary).
#
# **Goal of the challenge:**
# <ul>
# <li>Identify conditions that favor product return (eg what type of product is usually returned, which customer is more keen on returning a product, what type of order or purchase context most often leads to returns?)</li>
# <li>Build a return forecast template for each product from a shopping cart.
# </li>
# </ul>
#
# To go further: This project aimes at making stand out purchasing behaviors. With this knowledge, the e-merchant wishes to use this data to better plan his activity. In particular, he wants to forecast the turnover generated by his clients.
#
#
#
# **Training data:**
#
# There will be $N= 1067290$ lines of orders in the training dataset. For each order  the training dataset reports if the command has been returned (***ReturnQuantityBin***) and the quantity returned (***ReturnQuantity***). The column to target (***ReturnQuantityBin***) which is a binary column ($y = 1$ if returned and $y=0$ otherwise).
#
# **Test data:**
#
# The test data contain $N_\text{test} = 800468$ lines of orders. Everything else is similar to the training data.
#
#
# ## Additional Data
#
# As part of the challenge, two additional datasets are avalaible namely (**customers.csv**) and (**products.csv**). Those to sets contains informations on custmers and on the products. A good prediction model will necessarily require extraction of information comming from this dataset. Students are free to use these data as they see fit. Please keep in mind that both sets containes also customers and products that are not present in the training or test sets.
#
# A dictionnary of variables (**dictionnary.xlsx**) is avalaible in the folder containing the datasets. Please refer to it so as to have a definition of the variables at hand.
#
#
# ## The goal and the performance criterion
#
# In this challenge, we will use an evaluation metric, which is commonly used in binary prediction, namely the ROC AUC criteria. **The closest to 1 the better (be affarait if its below 0).**
# Hence the form of the file to send is of the form :
#
#
# | <center> probability </center>  |
# | ------------- |
# | <center> .90  </center>         |
# | <center> ...  </center>         |
# | <center> .42  </center>         |
#
#
# The order of the probabilities needs to respect the order in the test set.
#
#
#
# # Training Data
#
# https://www.dropbox.com/sh/uo4oudw43j45mp3/AACA0UqkitNKSWdE_7fs2Wbla?dl=0

# %%
from __future__ import division
#from importlib import reload
import os
import sys
#reload(sys)
#sys.setdefaultencoding("utf-8") -> PYTHON 2 ONLY

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import random
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ## Loading the data

# %%
customers = pd.read_csv("customers.csv")
products = pd.read_csv("products.csv")
X_train = pd.read_csv("X_train.csv")
X_test   = pd.read_csv("X_test.csv")
y_train = pd.read_csv("y_train.csv")

# %% [markdown]
# ## Defining a feature transformation

# %%
def funk_mask(d):
    " Defining a simple mask over the input data "
    columns_ext = ["OrderCreationDate","OrderNumber","VariantId", "CustomerId","OrderCreationDate","OrderShipDate","BillingPostalCode"]
    X1 = d.loc[:,[xx for xx in d.columns if xx not in columns_ext]]
    g = lambda x: x.replace(",",".")
    X1.UnitPMPEUR = map(np.float64,(map(g,X1.UnitPMPEUR)))
    columns2bin = [x for x in X1.columns if X1[x].dtype == np.dtype('O')]
    X2 = pd.get_dummies(X1.loc[:,columns2bin])
    X1 = X1.loc[:,[xx for xx in X1.columns if xx not in columns2bin]]
    res = pd.concat([X1,X2],axis=1)
    res = res.fillna(0)
    return(res)

# %% [markdown]
# ## Applying the mask

# %%
x1 = funk_mask(X_train)
x2 = funk_mask(X_test)
seleckt_columns = np.intersect1d(x1.columns,x2.columns)
x1 = x1.loc[:,seleckt_columns]
x2 = x2.loc[:,seleckt_columns]

# %% [markdown]
# ## Supervised learning : Logistic regression model

# %%
clf = LogisticRegression()
clf.fit(x1.iloc[:50000], y_train.ReturnQuantityBin[:50000])
y_tosubmit = clf.predict_proba(x2.loc[:,x1.columns])

# %% [markdown]
# ## Score of our prediction : on the train

# %%
yres = clf.predict_proba(x1.loc[:100000,x1.columns])
roc_auc_score(y_train.ReturnQuantityBin.iloc[:100001],yres[:,1])

# Submission to the system
np.savetxt('y_pred.txt', y_tosubmit[:,1], fmt='%f')

# %% [markdown]
# # <center> That's all folks; Good Luck! </center>

# %%
print("CUSTOMERS :")
customers.head()
# Out:
# CUSTOMERS :
#    CustomerId CountryISOCode            BirthDate Gender       FirstOrderDate
# 0  14089083.0             SE  1979-02-05 00:00:00  Femme  2013-03-16 23:00:05
# 1  12862066.0             FR  1982-08-04 00:00:00  Femme  2012-02-14 17:47:33
# 2  14791699.0             FR  1965-04-02 00:00:00  Femme  2013-10-04 23:10:42
# 3  10794664.0             FR  1966-04-09 00:00:00  Femme  2010-03-25 18:46:59
# 4  15268576.0             ES  1980-04-22 00:00:00  Femme  2014-03-19 10:48:39

# %%
print("PRODUCTS :")
products.head()
# Out:
# PRODUCTS :
#    VariantId GenderLabel MarketTargetLabel    SeasonLabel SeasonalityLabel  \
# 0   728257.0       Homme         Classique  Automne/Hiver       Saisonnier
# 1   806356.0       Femme                ND  Automne/Hiver       Saisonnier
# 2   768790.0       Femme                ND  Automne/Hiver        Reconduit
# 3   515679.0       Femme                ND  Automne/Hiver       Saisonnier
# 4  1025246.0       Femme                ND  Automne/Hiver       Saisonnier
#
#    BrandId UniverseLabel TypeBrand  ProductId        ProductType  \
# 0     66.0      DÃ©tente  Standard    17267.0            Baskets
# 1    842.0            ND  Standard    30824.0            Baskets
# 2    988.0         Ville  Standard    62475.0  Bottines et boots
# 3    769.0         Ville  Standard    43983.0          Escarpins
# 4   1244.0            ND  Standard    81493.0  Bottines et boots
#
#                          ...                         UpperHeight  HeelHeight  \
# 0                        ...                                 NaN         0.0
# 1                        ...                                 0.0         0.0
# 2                        ...                                 6.0         3.0
# 3                        ...                                 0.0        13.0
# 4                        ...                                 8.0         4.0
#
#    PurchasePriceHT  IsNewCollection  SubtypeLabel  UpperMaterialLabel  \
# 0            30.50              0.0     Montantes                 NaN
# 1            43.00              0.0     Montantes                 NaN
# 2            54.90              0.0   Bout pointu                 NaN
# 3            34.50              0.0     Bout rond                 NaN
# 4            43.76              0.0     Bout rond                 NaN
#
#    LiningMaterialLabel  OutSoleMaterialLabel  RemovableSole  \
# 0                  NaN                   NaN          False
# 1                  NaN                   NaN           True
# 2                  NaN                   NaN          False
# 3                  NaN                   NaN          False
# 4                  NaN                   NaN          False
#
#                                SizeAdviceDescription
# 0  Prenez une taille en dessous de votre pointure...
# 1                   Prenez votre pointure habituelle
# 2                   Prenez votre pointure habituelle
# 3                   Prenez votre pointure habituelle
# 4                   Prenez votre pointure habituelle
#
# [5 rows x 25 columns]

# %%
X_train.head()
# Out:
#    OrderNumber  VariantId  LineItem  CustomerId OrderStatusLabel  \
# 0     73521754     439729         1    12443972          Expédié
# 1     73521754     440174         2    12443972          Expédié
# 2     73525226     494501         1    12443958          Expédié
# 3     73529009     439590         1    12443946          Expédié
# 4     73529009     559476         2    12443946          Expédié
#
#   OrderTypelabel    SeasonLabel PayementModeLabel CustomerTypeLabel IsoCode  \
# 0         DIRECT  Automne/Hiver    Carte bancaire           Nouveau      FR
# 1         DIRECT  Automne/Hiver    Carte bancaire           Nouveau      FR
# 2         DIRECT  Automne/Hiver    Carte bancaire           Nouveau      FR
# 3         DIRECT  Automne/Hiver    Carte bancaire           Nouveau      FR
# 4         DIRECT  Automne/Hiver    Carte bancaire           Nouveau      FR
#
#   DeviceTypeLabel PricingTypeLabel  TotalLineItems  Quantity UnitPMPEUR  \
# 0              ND      Plein Tarif               2         1      52,64
# 1              ND      Plein Tarif               2         1      52,64
# 2              ND      Plein Tarif               1         1      13,17
# 3              ND      Plein Tarif               2         1       56,4
# 4              ND      Plein Tarif               2         1         37
#
#      OrderCreationDate        OrderShipDate  OrderNumCustomer  IsOnSale  \
# 0  2011-10-26 12:10:48  2011-10-26 18:27:00                 1       0.0
# 1  2011-10-26 12:10:48  2011-10-26 18:27:00                 1       0.0
# 2  2011-10-26 12:11:38  2011-10-26 17:48:00                 1       0.0
# 3  2011-10-26 12:13:09  2011-10-26 17:59:00                 1       0.0
# 4  2011-10-26 12:13:09  2011-10-26 17:59:00                 1       0.0
#
#   BillingPostalCode
# 0             87000
# 1             87000
# 2             77700
# 3             44600
# 4             44600

# %%
d1 = "1969-10-03 00:00:00"
from datetime import datetime

try:
    from tqdm import tqdm_notebook as tqdm
except :
    print("tqdm non installé. Lancez 'pip install tqdm' dans un terminal et relancez la cellule.")

    
    
def age_from_date(date):
    try:
        d = datetime.strptime(date,"%Y-%m-%d %H:%M:%S")
    except:
        d = datetime.strptime(date[0:19],"%Y-%m-%d %H:%M:%S")
    now = datetime.now()
    delta = now.year - d.year
    if (now.month == d.month and now.day<d.day):
        delta-=1
    if now.month < d.month:
        delta-=1
    return delta

age_from_date(d1)
# Out:
# 48

# %%
from tqdm import tqdm_notebook as tqdm

tabAge = []
for date in tqdm(customers["BirthDate"]):
    tabAge.append(age_from_date(date))
customers["Age"] = tabAge
# Out:
# HBox(children=(IntProgress(value=0, max=780238), HTML(value='')))

# %%
customers.head()
# Out:
#    CustomerId CountryISOCode            BirthDate Gender       FirstOrderDate  \
# 0  14089083.0             SE  1979-02-05 00:00:00  Femme  2013-03-16 23:00:05
# 1  12862066.0             FR  1982-08-04 00:00:00  Femme  2012-02-14 17:47:33
# 2  14791699.0             FR  1965-04-02 00:00:00  Femme  2013-10-04 23:10:42
# 3  10794664.0             FR  1966-04-09 00:00:00  Femme  2010-03-25 18:46:59
# 4  15268576.0             ES  1980-04-22 00:00:00  Femme  2014-03-19 10:48:39
#
#    Age
# 0   39
# 1   35
# 2   53
# 3   51
# 4   37

# %%
X_train.head()
# Out:
#    OrderNumber  VariantId  LineItem  CustomerId OrderStatusLabel  \
# 0     73521754     439729         1    12443972          Expédié
# 1     73521754     440174         2    12443972          Expédié
# 2     73525226     494501         1    12443958          Expédié
# 3     73529009     439590         1    12443946          Expédié
# 4     73529009     559476         2    12443946          Expédié
#
#   OrderTypelabel    SeasonLabel PayementModeLabel CustomerTypeLabel IsoCode  \
# 0         DIRECT  Automne/Hiver    Carte bancaire           Nouveau      FR
# 1         DIRECT  Automne/Hiver    Carte bancaire           Nouveau      FR
# 2         DIRECT  Automne/Hiver    Carte bancaire           Nouveau      FR
# 3         DIRECT  Automne/Hiver    Carte bancaire           Nouveau      FR
# 4         DIRECT  Automne/Hiver    Carte bancaire           Nouveau      FR
#
#   DeviceTypeLabel PricingTypeLabel  TotalLineItems  Quantity UnitPMPEUR  \
# 0              ND      Plein Tarif               2         1      52,64
# 1              ND      Plein Tarif               2         1      52,64
# 2              ND      Plein Tarif               1         1      13,17
# 3              ND      Plein Tarif               2         1       56,4
# 4              ND      Plein Tarif               2         1         37
#
#      OrderCreationDate        OrderShipDate  OrderNumCustomer  IsOnSale  \
# 0  2011-10-26 12:10:48  2011-10-26 18:27:00                 1       0.0
# 1  2011-10-26 12:10:48  2011-10-26 18:27:00                 1       0.0
# 2  2011-10-26 12:11:38  2011-10-26 17:48:00                 1       0.0
# 3  2011-10-26 12:13:09  2011-10-26 17:59:00                 1       0.0
# 4  2011-10-26 12:13:09  2011-10-26 17:59:00                 1       0.0
#
#   BillingPostalCode
# 0             87000
# 1             87000
# 2             77700
# 3             44600
# 4             44600

# %%
tab = pd.merge(customers, X_train)

# %%
del tab['FirstOrderDate']
del tab['BirthDate']
del tab['OrderCreationDate']
del tab['OrderShipDate']

# %%
tab.head()
# Out:
#     CustomerId CountryISOCode Gender  Age  OrderNumber  VariantId  LineItem  \
# 0  1.40891e+07             SE  Femme   39     89882287     728257         1
# 1  1.40891e+07             SE  Femme   39     89882287     806356         2
# 2  1.28621e+07             FR  Femme   35     67014446     288068         1
# 3  1.28621e+07             FR  Femme   35     67014446     515679         2
# 4  1.28621e+07             FR  Femme   35     24318335     678091         1
#
#   OrderStatusLabel OrderTypelabel    SeasonLabel PayementModeLabel  \
# 0          Expédié         DIRECT  Printemps/Eté    Carte bancaire
# 1          Expédié         DIRECT  Automne/Hiver    Carte bancaire
# 2          Expédié         DIRECT  Automne/Hiver            PayPal
# 3          Expédié         DIRECT  Automne/Hiver            PayPal
# 4          Expédié         DIRECT  Printemps/Eté            PayPal
#
#   CustomerTypeLabel IsoCode DeviceTypeLabel PricingTypeLabel  TotalLineItems  \
# 0           Nouveau      SE              ND    Promo Sans CP               2
# 1           Nouveau      SE              ND    Promo Sans CP               2
# 2           Nouveau      FR              ND           Soldes               2
# 3           Nouveau      FR              ND      Plein Tarif               2
# 4          Fidélisé      FR              ND    Promo Avec CP               1
#
#    Quantity  UnitPMPEUR  OrderNumCustomer  IsOnSale
# 0         1     24.3430                 1       0.0
# 1         1     32.8711                 1       0.0
# 2         1     38.6400                 1       1.0
# 3         1     32.7700                 1       0.0
# 4         1     38.2200                 2       0.0

# %%
s='saousan'

# %%
column = []
for i in tqdm(range(len(tab["UnitPMPEUR"]))):
    column.append(tab["UnitPMPEUR"][i].replace(",","."))
tab["UnitPMPEUR"] = column;
# Out:
# HBox(children=(IntProgress(value=0, max=790413), HTML(value='')))

# %%
tab['UnitPMPEUR']=tab['UnitPMPEUR'].astype(float)

# %%
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.ensemble import BaggingRegressor, RandomForestRegressor, RandomForestClassifier
import matplotlib as mpl
from sklearn.metrics import r2_score as r2
from matplotlib.pyplot import cm 
from sklearn import datasets, svm, preprocessing
from sklearn.model_selection import cross_val_score

# %%
del tab["BillingPostalCode"]

# %%
cols_to_transform = [ 'CountryISOCode', 'Gender', 'OrderStatusLabel', 'OrderTypelabel', 'SeasonLabel', 'PayementModeLabel','CustomerTypeLabel','IsoCode','DeviceTypeLabel','PricingTypeLabel' ]
tab = pd.get_dummies( tab,columns = cols_to_transform )

# %%
tree = DecisionTreeClassifier(max_depth= 30)
tree.fit(tab,y_train )


bagging = BaggingRegressor(base_estimator=tree)
bagging.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-09b1d1bf4c08> in <module>()
#       2
#       3 tree = DecisionTreeClassifier(max_depth= 30)
# ----> 4 tree.fit(tab,y_train )
#       5
#       6
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     788             sample_weight=sample_weight,
#     789             check_input=check_input,
# --> 790             X_idx_sorted=X_idx_sorted)
#     791         return self
#     792
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     114         random_state = check_random_state(self.random_state)
#     115         if check_input:
# --> 116             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     117             y = check_array(y, ensure_2d=False, dtype=None)
#     118             if issparse(X):
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     451                              % (array.ndim, estimator_name))
#     452         if force_all_finite:
# --> 453             _assert_all_finite(array)
#     454
#     455     shape_repr = _shape_repr(array.shape)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X)
#      42             and not np.isfinite(X).all()):
#      43         raise ValueError("Input contains NaN, infinity"
# ---> 44                          " or a value too large for %r." % X.dtype)
#      45
#      46
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
tab.tail()
# Out:
#          CustomerId CountryISOCode Gender  Age  OrderNumber  VariantId  \
# 790408   1.4585e+07             NL  Femme   38     62112457     592732
# 790409   1.4243e+07             FR  Femme   48     61488192     938737
# 790410  1.37118e+07             FR  Femme   30     70803896     538985
# 790411  1.31541e+07             FR  Femme   34     60877753     430461
# 790412   1.3176e+07             IT  Femme   43     10409304     574985
#
#         LineItem OrderStatusLabel OrderTypelabel    SeasonLabel  \
# 790408         1          Expédié         DIRECT  Printemps/Eté
# 790409         1          Expédié         DIRECT  Printemps/Eté
# 790410         1          Expédié         DIRECT  Automne/Hiver
# 790411         1          Expédié         DIRECT  Printemps/Eté
# 790412         1          Expédié         DIRECT  Printemps/Eté
#
#        PayementModeLabel CustomerTypeLabel IsoCode DeviceTypeLabel  \
# 790408    Carte bancaire           Nouveau      NL          Tablet
# 790409    Carte bancaire           Nouveau      FR              ND
# 790410    Carte bancaire           Nouveau      FR              ND
# 790411    Carte bancaire           Nouveau      FR              ND
# 790412    Carte bancaire           Nouveau      IT              ND
#
#        PricingTypeLabel  TotalLineItems  Quantity  UnitPMPEUR  \
# 790408    Promo Avec CP               1         1     34.0200
# 790409      Plein Tarif               1         1     17.8000
# 790410    Promo Avec CP               1         1     75.0000
# 790411    Promo Avec CP               1         1     24.9500
# 790412      Plein Tarif               1         1     12.0058
#
#         OrderNumCustomer  IsOnSale
# 790408                 1       0.0
# 790409                 1       0.0
# 790410                 1       0.0
# 790411                 1       0.0
# 790412                 1       0.0

# %%
y_train.head()
